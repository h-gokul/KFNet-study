# %% [markdown]
# # Visualize Point Clouds
#
# The scene coordinates aka point clouds can be visualized in this notebook.
# We had already extracted the `process/measurement/filtered` scene coordinates $\theta_t$ ,  for `fire` and `heads` data in the `7 scenes dataset`

# %%
from glob import glob
import numpy as np
import open3d
import time
import matplotlib.pyplot as plt
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# # Step 1: Generate the IMAGE and LABEL list, in the ```input/``` folder

# %%
folder = 'fire'
sequence = 'seq-01'

# [UNCOMMENT BELOW CODE]: TO GENERATE LABEL LIST and IMAGE LIST

# BIN_DIR = f"./input/{folder}-label/{sequence}/bin"
# N = len(glob(f"{BIN_DIR}/*.bin"))
# files = [f"{BIN_DIR}/{str(i)}.bin"  for i in range(N)]
# np.savetxt('./input/label_list.txt', np.array(files), fmt='%s')


# N = len(glob(f"./input/{folder}-input-images/{sequence}/*.color.png"))
# files = sorted(glob(f"./input/{folder}-input-images/{sequence}/*.color.png"))
# np.savetxt(f'./input/image_list.txt', np.array(files), fmt='%s')

# %% [markdown]
# # Step2: Run Evaluation
# - download the models and place in the models folder.
# - download the data  sequence from 7 scenes for images and the prepared groundtruth labels from the authors. Further details are given [here](https://github.com/zlthinker/KFNet)
# - use docker in the terminal to load to the workspace and execute evaluation.
# - run the evaluation script using the following command
#
# - Example:
#  `python KFNet/eval.py --input_folder ./input --output_folder ./output/fire --model_folder ./models/KFNet/heads --scene fire`
# - note the distance errors
# - save the scene coords in the output folder

# %% [markdown]
# # Visualize Point Clouds
# - specify the scene and the model

# %% [markdown]
# ## Functions

# %%
def pointcloud_to_depth_map(pointcloud: np.ndarray, theta_res=150, phi_res=32, max_depth=50, phi_min_degrees=60,
                            phi_max_degrees=100) -> np.ndarray:
    """
        All params are set so they match default carla lidar settings
    """
    assert pointcloud.shape[1] == 3, 'Must have (N, 3) shape'
    assert len(pointcloud.shape) == 2, 'Must have (N, 3) shape'

    xs = pointcloud[:, 0]
    ys = pointcloud[:, 1]
    zs = pointcloud[:, 2]

    rs = np.sqrt(np.square(xs) + np.square(ys) + np.square(zs))

    phi_min = np.deg2rad(phi_min_degrees)
    phi_max = np.deg2rad(phi_max_degrees)
    phi_range = phi_max - phi_min
    phis = np.arccos(zs / rs)

    THETA_MIN = -np.pi
    THETA_MAX = np.pi
    THETA_RANGE = THETA_MAX - THETA_MIN
    thetas = np.arctan2(xs, ys)

    phi_indices = ((phis - phi_min) / phi_range) * (phi_res - 1)
    phi_indices = np.rint(phi_indices).astype(np.int16)

    theta_indices = ((thetas - THETA_MIN) / THETA_RANGE) * theta_res
    theta_indices = np.rint(theta_indices).astype(np.int16)
    theta_indices[theta_indices == theta_res] = 0

    normalized_r = rs / max_depth

    canvas = np.ones(shape=(theta_res, phi_res), dtype=np.float32)
    # We might need to filter out out-of-bound phi values, if min-max degrees doesnt match lidar settings
    canvas[theta_indices, phi_indices] = normalized_r

    depth_map = canvas * 256
    depth_map = np.flip(depth_map, axis=1) # so floor is down
    depth_map = np.swapaxes(depth_map, 0, 1)    
    return depth_map

import math
def rotation_matrix(angle, direction, point=None):
    sina = math.sin(angle)
    cosa = math.cos(angle)
    # rotation matrix around unit vector
    R = np.diag([cosa, cosa, cosa])
    R += np.outer(direction, direction) * (1.0 - cosa)
    print( direction, direction.dtype)
    direction *= sina
    R += np.array([[ 0.0,         -direction[2],  direction[1]],
                      [ direction[2], 0.0,          -direction[0]],
                      [-direction[1], direction[0],  0.0]])
    M = np.identity(4)
    M[:3, :3] = R
    if point is not None:
        # rotation not around origin
        point = np.array(point[:3], dtype=np.float64, copy=False)
        M[:3, 3] = point - np.dot(R, point)
    return M

def filter_pointclouds(npy_file, thres=None):
    # added auto-thresholding
    map = np.load(npy_file)
    coords = map[:, :, 0:3]
    confidences = map[:, :, 3]
    if not thres:
        thres = 0.3*np.max(confidences) 

    coords = np.reshape(coords, (-1, 3))
    confidences = confidences.flatten().tolist()

    coords_filtered = []
    for i in range(len(confidences)):
        if confidences[i] > thres:
            coords_filtered.append(coords[i])
    coords_filtered = np.vstack(coords_filtered)
    return coords_filtered

def read_pointclouds(npy_file, thres):
    coords_filtered = filter_pointclouds(npy_file, thres)
    print ('Load #points:', coords_filtered.shape[0], ' from', npy_file)
    pcd = open3d.geometry.PointCloud()
    pcd.points = open3d.utility.Vector3dVector(coords_filtered)
    return pcd

# %%
# For PnP

# # TO GENERATE POSE LIST
# # posefiles = sorted(glob(f"input/{folder}-input-images/{sequence}/*pose.txt"))
# # print(len(posefiles))
# # if len(posefiles):
# #     np.savetxt( f"output/KFNet/pnpfiles/{folder}/gtposefiles.txt" ,np.array(posefiles), fmt='%s') 


# folder = 'fire'
# sequence = 'seq-01'


# # TO GENERATE OUTPUT LIST
# coordfiles = sorted(glob(f"output/KFNet/scenecoords/{folder}/*.npy"))
# print(len(coordfiles))
# if len(coordfiles):
#     np.savetxt( f"output/KFNet/pnpfiles/{folder}/coordfiles.txt" ,np.array(coordfiles), fmt='%s')

# %% [markdown]
# ## To visualize the states.

# %%
folder = 'fireD_headsM' # heads
type =  'measured' # filtered # process # measured

# To visualize process states
files = sorted(glob(f"output/{folder}/{type}/*.npy"))
coordfiles = [f"output/{folder}/{type}/coord_{str(i)}.npy" for i in range(len(files))]

print(f"Number of point clouds in {type}: ", len(coordfiles))
print("shape of point clouds:", np.load(coordfiles[0]).shape)
# Out:
# Number of point clouds in measured:  1000
# shape of point clouds: (60, 80, 4)

# %% [markdown]
# ## Run Visualizer

# %%
rotate= 180 #deg
rotation = rotation_matrix(math.pi * rotate / 180.0, np.array([1.0, 0.0, 0.0]))
print('rotation', rotation)


vis = open3d.visualization.Visualizer()
vis.create_window()

line_set = open3d.geometry.LineSet()
line_set.transform(rotation)
for i in range(0, len(coordfiles), 1 ):
    npy_file = coordfiles[i]
    pcd = read_pointclouds(npy_file, None)
    print()
    pcd.transform(rotation)

    vis.add_geometry(pcd)
    vis.update_geometry(None)
    vis.poll_events()
    vis.update_renderer()
    time.sleep(0.05 * 1)
vis.destroy_window()
# Out:
# [1. 0. 0.] float64
# rotation [[ 1.0000000e+00  0.0000000e+00  0.0000000e+00  0.0000000e+00]
#  [ 0.0000000e+00 -1.0000000e+00 -1.2246468e-16  0.0000000e+00]
#  [ 0.0000000e+00  1.2246468e-16 -1.0000000e+00  0.0000000e+00]
#  [ 0.0000000e+00  0.0000000e+00  0.0000000e+00  1.0000000e+00]]
# Load #points: 258  from output/fireD_headsM/measured/coord_0.npy
#
# Load #points: 243  from output/fireD_headsM/measured/coord_1.npy
#
# Load #points: 262  from output/fireD_headsM/measured/coord_2.npy
#
# Load #points: 272  from output/fireD_headsM/measured/coord_3.npy
#
# Load #points: 257  from output/fireD_headsM/measured/coord_4.npy
#
# Load #points: 281  from output/fireD_headsM/measured/coord_5.npy
#
# Load #points: 202  from output/fireD_headsM/measured/coord_6.npy
#
# Load #points: 218  from output/fireD_headsM/measured/coord_7.npy
#
# Load #points: 274  from output/fireD_headsM/measured/coord_8.npy
#
# Load #points: 268  from output/fireD_headsM/measured/coord_9.npy
#
# Load #points: 207  from output/fireD_headsM/measured/coord_10.npy
#
# Load #points: 288  from output/fireD_headsM/measured/coord_11.npy
#
# Load #points: 239  from output/fireD_headsM/measured/coord_12.npy
#
# Load #points: 293  from output/fireD_headsM/measured/coord_13.npy
#
# Load #points: 247  from output/fireD_headsM/measured/coord_14.npy
#
# Load #points: 225  from output/fireD_headsM/measured/coord_15.npy
#
# Load #points: 235  from output/fireD_headsM/measured/coord_16.npy
#
# Load #points: 247  from output/fireD_headsM/measured/coord_17.npy
#
# Load #points: 230  from output/fireD_headsM/measured/coord_18.npy
#
# Load #points: 223  from output/fireD_headsM/measured/coord_19.npy
#
# Load #points: 232  from output/fireD_headsM/measured/coord_20.npy
#
# Load #points: 321  from output/fireD_headsM/measured/coord_21.npy
#
# Load #points: 384  from output/fireD_headsM/measured/coord_22.npy
#
# Load #points: 379  from output/fireD_headsM/measured/coord_23.npy
#
# Load #points: 342  from output/fireD_headsM/measured/coord_24.npy
#
# Load #points: 373  from output/fireD_headsM/measured/coord_25.npy
#
# Load #points: 305  from output/fireD_headsM/measured/coord_26.npy
#
# Load #points: 336  from output/fireD_headsM/measured/coord_27.npy
#
# Load #points: 380  from output/fireD_headsM/measured/coord_28.npy
#
# Load #points: 436  from output/fireD_headsM/measured/coord_29.npy
#
# Load #points: 394  from output/fireD_headsM/measured/coord_30.npy
#
# Load #points: 467  from output/fireD_headsM/measured/coord_31.npy
#
# Load #points: 355  from output/fireD_headsM/measured/coord_32.npy
#
# Load #points: 346  from output/fireD_headsM/measured/coord_33.npy
#
# Load #points: 321  from output/fireD_headsM/measured/coord_34.npy
#
# Load #points: 380  from output/fireD_headsM/measured/coord_35.npy
#
# Load #points: 395  from output/fireD_headsM/measured/coord_36.npy
#
# Load #points: 362  from output/fireD_headsM/measured/coord_37.npy
#
# Load #points: 362  from output/fireD_headsM/measured/coord_38.npy
#
# Load #points: 312  from output/fireD_headsM/measured/coord_39.npy
#
# Load #points: 359  from output/fireD_headsM/measured/coord_40.npy
#
# Load #points: 282  from output/fireD_headsM/measured/coord_41.npy
#
# Load #points: 327  from output/fireD_headsM/measured/coord_42.npy
#
# Load #points: 347  from output/fireD_headsM/measured/coord_43.npy
#
# Load #points: 230  from output/fireD_headsM/measured/coord_44.npy
#
# Load #points: 402  from output/fireD_headsM/measured/coord_45.npy
#
# Load #points: 403  from output/fireD_headsM/measured/coord_46.npy
#
# Load #points: 341  from output/fireD_headsM/measured/coord_47.npy
#
# Load #points: 341  from output/fireD_headsM/measured/coord_48.npy
#
# Load #points: 317  from output/fireD_headsM/measured/coord_49.npy
#
# Load #points: 351  from output/fireD_headsM/measured/coord_50.npy
#
# Load #points: 393  from output/fireD_headsM/measured/coord_51.npy
#
# Load #points: 381  from output/fireD_headsM/measured/coord_52.npy
#
# Load #points: 394  from output/fireD_headsM/measured/coord_53.npy
#
# Load #points: 485  from output/fireD_headsM/measured/coord_54.npy
#
# Load #points: 582  from output/fireD_headsM/measured/coord_55.npy
#
# Load #points: 582  from output/fireD_headsM/measured/coord_56.npy
#
# Load #points: 511  from output/fireD_headsM/measured/coord_57.npy
#
# Load #points: 349  from output/fireD_headsM/measured/coord_58.npy
#
# Load #points: 274  from output/fireD_headsM/measured/coord_59.npy
#
# Load #points: 449  from output/fireD_headsM/measured/coord_60.npy
#
# Load #points: 377  from output/fireD_headsM/measured/coord_61.npy
#
# Load #points: 336  from output/fireD_headsM/measured/coord_62.npy
#
# Load #points: 364  from output/fireD_headsM/measured/coord_63.npy
#
# Load #points: 420  from output/fireD_headsM/measured/coord_64.npy
#
# Load #points: 420  from output/fireD_headsM/measured/coord_65.npy
#
# Load #points: 342  from output/fireD_headsM/measured/coord_66.npy
#
# Load #points: 238  from output/fireD_headsM/measured/coord_67.npy
#
# Load #points: 231  from output/fireD_headsM/measured/coord_68.npy
#
# Load #points: 192  from output/fireD_headsM/measured/coord_69.npy
#
# Load #points: 223  from output/fireD_headsM/measured/coord_70.npy
#
# Load #points: 232  from output/fireD_headsM/measured/coord_71.npy
#
# Load #points: 181  from output/fireD_headsM/measured/coord_72.npy
#
# Load #points: 162  from output/fireD_headsM/measured/coord_73.npy
#
# Load #points: 247  from output/fireD_headsM/measured/coord_74.npy
#
# Load #points: 273  from output/fireD_headsM/measured/coord_75.npy
#
# Load #points: 305  from output/fireD_headsM/measured/coord_76.npy
#
# Load #points: 305  from output/fireD_headsM/measured/coord_77.npy
#
# Load #points: 314  from output/fireD_headsM/measured/coord_78.npy
#
# Load #points: 235  from output/fireD_headsM/measured/coord_79.npy
#
# Load #points: 305  from output/fireD_headsM/measured/coord_80.npy
#
# Load #points: 233  from output/fireD_headsM/measured/coord_81.npy
#
# Load #points: 266  from output/fireD_headsM/measured/coord_82.npy
#
# Load #points: 288  from output/fireD_headsM/measured/coord_83.npy
#
# Load #points: 280  from output/fireD_headsM/measured/coord_84.npy
#
# Load #points: 314  from output/fireD_headsM/measured/coord_85.npy
#
# Load #points: 273  from output/fireD_headsM/measured/coord_86.npy
#
# Load #points: 293  from output/fireD_headsM/measured/coord_87.npy
#
# Load #points: 272  from output/fireD_headsM/measured/coord_88.npy
#
# Load #points: 269  from output/fireD_headsM/measured/coord_89.npy
#
# Load #points: 367  from output/fireD_headsM/measured/coord_90.npy
#
# Load #points: 308  from output/fireD_headsM/measured/coord_91.npy
#
# Load #points: 315  from output/fireD_headsM/measured/coord_92.npy
#
# Load #points: 303  from output/fireD_headsM/measured/coord_93.npy
#
# Load #points: 237  from output/fireD_headsM/measured/coord_94.npy
#
# Load #points: 242  from output/fireD_headsM/measured/coord_95.npy
#
# Load #points: 301  from output/fireD_headsM/measured/coord_96.npy
#
# Load #points: 302  from output/fireD_headsM/measured/coord_97.npy
#
# Load #points: 262  from output/fireD_headsM/measured/coord_98.npy
#
# Load #points: 239  from output/fireD_headsM/measured/coord_99.npy
#
# Load #points: 203  from output/fireD_headsM/measured/coord_100.npy
#
# Load #points: 174  from output/fireD_headsM/measured/coord_101.npy
#
# Load #points: 267  from output/fireD_headsM/measured/coord_102.npy
#
# Load #points: 245  from output/fireD_headsM/measured/coord_103.npy
#
# Load #points: 253  from output/fireD_headsM/measured/coord_104.npy
#
# Load #points: 206  from output/fireD_headsM/measured/coord_105.npy
#
# Load #points: 240  from output/fireD_headsM/measured/coord_106.npy
#
# Load #points: 221  from output/fireD_headsM/measured/coord_107.npy
#
# Load #points: 208  from output/fireD_headsM/measured/coord_108.npy
#
# Load #points: 191  from output/fireD_headsM/measured/coord_109.npy
#
# Load #points: 187  from output/fireD_headsM/measured/coord_110.npy
#
# Load #points: 185  from output/fireD_headsM/measured/coord_111.npy
#
# Load #points: 190  from output/fireD_headsM/measured/coord_112.npy
#
# Load #points: 185  from output/fireD_headsM/measured/coord_113.npy
#
# Load #points: 172  from output/fireD_headsM/measured/coord_114.npy
#
# Load #points: 196  from output/fireD_headsM/measured/coord_115.npy
#
# Load #points: 192  from output/fireD_headsM/measured/coord_116.npy
#
# Load #points: 203  from output/fireD_headsM/measured/coord_117.npy
#
# Load #points: 188  from output/fireD_headsM/measured/coord_118.npy
#
# Load #points: 201  from output/fireD_headsM/measured/coord_119.npy
#
# Load #points: 220  from output/fireD_headsM/measured/coord_120.npy
#
# Load #points: 205  from output/fireD_headsM/measured/coord_121.npy
#
# Load #points: 269  from output/fireD_headsM/measured/coord_122.npy
#
# Load #points: 233  from output/fireD_headsM/measured/coord_123.npy
#
# Load #points: 271  from output/fireD_headsM/measured/coord_124.npy
#
# Load #points: 254  from output/fireD_headsM/measured/coord_125.npy
#
# Load #points: 247  from output/fireD_headsM/measured/coord_126.npy
#
# Load #points: 314  from output/fireD_headsM/measured/coord_127.npy
#
# Load #points: 281  from output/fireD_headsM/measured/coord_128.npy
#
# Load #points: 266  from output/fireD_headsM/measured/coord_129.npy
#
# Load #points: 306  from output/fireD_headsM/measured/coord_130.npy
#
# Load #points: 290  from output/fireD_headsM/measured/coord_131.npy
#
# Load #points: 297  from output/fireD_headsM/measured/coord_132.npy
#
# Load #points: 259  from output/fireD_headsM/measured/coord_133.npy
#
# Load #points: 369  from output/fireD_headsM/measured/coord_134.npy
#
# Load #points: 353  from output/fireD_headsM/measured/coord_135.npy
#
# Load #points: 309  from output/fireD_headsM/measured/coord_136.npy
#
# Load #points: 223  from output/fireD_headsM/measured/coord_137.npy
#
# Load #points: 227  from output/fireD_headsM/measured/coord_138.npy
#
# Load #points: 233  from output/fireD_headsM/measured/coord_139.npy
#
# Load #points: 399  from output/fireD_headsM/measured/coord_140.npy
#
# Load #points: 360  from output/fireD_headsM/measured/coord_141.npy
#
# Load #points: 335  from output/fireD_headsM/measured/coord_142.npy
#
# Load #points: 495  from output/fireD_headsM/measured/coord_143.npy
#
# Load #points: 401  from output/fireD_headsM/measured/coord_144.npy
#
# Load #points: 297  from output/fireD_headsM/measured/coord_145.npy
#
# Load #points: 353  from output/fireD_headsM/measured/coord_146.npy
#
# Load #points: 428  from output/fireD_headsM/measured/coord_147.npy
#
# Load #points: 389  from output/fireD_headsM/measured/coord_148.npy
#
# Load #points: 482  from output/fireD_headsM/measured/coord_149.npy
#
# Load #points: 532  from output/fireD_headsM/measured/coord_150.npy
#
# Load #points: 398  from output/fireD_headsM/measured/coord_151.npy
#
# Load #points: 372  from output/fireD_headsM/measured/coord_152.npy
#
# Load #points: 337  from output/fireD_headsM/measured/coord_153.npy
#
# Load #points: 581  from output/fireD_headsM/measured/coord_154.npy
#
# Load #points: 385  from output/fireD_headsM/measured/coord_155.npy
#
# Load #points: 546  from output/fireD_headsM/measured/coord_156.npy
#
# Load #points: 722  from output/fireD_headsM/measured/coord_157.npy
#
# Load #points: 373  from output/fireD_headsM/measured/coord_158.npy
#
# Load #points: 583  from output/fireD_headsM/measured/coord_159.npy
#
# Load #points: 673  from output/fireD_headsM/measured/coord_160.npy
#
# Load #points: 616  from output/fireD_headsM/measured/coord_161.npy
#
# Load #points: 561  from output/fireD_headsM/measured/coord_162.npy
#
# Load #points: 561  from output/fireD_headsM/measured/coord_163.npy
#
# Load #points: 509  from output/fireD_headsM/measured/coord_164.npy
#
# Load #points: 459  from output/fireD_headsM/measured/coord_165.npy
#
# Load #points: 459  from output/fireD_headsM/measured/coord_166.npy
#
# Load #points: 361  from output/fireD_headsM/measured/coord_167.npy
#
# Load #points: 373  from output/fireD_headsM/measured/coord_168.npy
#
# Load #points: 433  from output/fireD_headsM/measured/coord_169.npy
#
# Load #points: 433  from output/fireD_headsM/measured/coord_170.npy
#
# Load #points: 386  from output/fireD_headsM/measured/coord_171.npy
#
# Load #points: 367  from output/fireD_headsM/measured/coord_172.npy
#
# Load #points: 499  from output/fireD_headsM/measured/coord_173.npy
#
# Load #points: 464  from output/fireD_headsM/measured/coord_174.npy
#
# Load #points: 464  from output/fireD_headsM/measured/coord_175.npy
#
# Load #points: 488  from output/fireD_headsM/measured/coord_176.npy
#
# Load #points: 465  from output/fireD_headsM/measured/coord_177.npy
#
# Load #points: 437  from output/fireD_headsM/measured/coord_178.npy
#
# Load #points: 437  from output/fireD_headsM/measured/coord_179.npy
#
# Load #points: 456  from output/fireD_headsM/measured/coord_180.npy
#
# Load #points: 433  from output/fireD_headsM/measured/coord_181.npy
#
# Load #points: 471  from output/fireD_headsM/measured/coord_182.npy
#
# Load #points: 551  from output/fireD_headsM/measured/coord_183.npy
#
# Load #points: 551  from output/fireD_headsM/measured/coord_184.npy
#
# Load #points: 429  from output/fireD_headsM/measured/coord_185.npy
#
# Load #points: 415  from output/fireD_headsM/measured/coord_186.npy
#
# Load #points: 400  from output/fireD_headsM/measured/coord_187.npy
#
# Load #points: 305  from output/fireD_headsM/measured/coord_188.npy
#
# Load #points: 353  from output/fireD_headsM/measured/coord_189.npy
#
# Load #points: 397  from output/fireD_headsM/measured/coord_190.npy
#
# Load #points: 320  from output/fireD_headsM/measured/coord_191.npy
#
# Load #points: 320  from output/fireD_headsM/measured/coord_192.npy
#
# Load #points: 361  from output/fireD_headsM/measured/coord_193.npy
#
# Load #points: 395  from output/fireD_headsM/measured/coord_194.npy
#
# Load #points: 371  from output/fireD_headsM/measured/coord_195.npy
#
# Load #points: 410  from output/fireD_headsM/measured/coord_196.npy
#
# Load #points: 419  from output/fireD_headsM/measured/coord_197.npy
#
# Load #points: 379  from output/fireD_headsM/measured/coord_198.npy
#
# Load #points: 379  from output/fireD_headsM/measured/coord_199.npy
#
# Load #points: 390  from output/fireD_headsM/measured/coord_200.npy
#
# Load #points: 377  from output/fireD_headsM/measured/coord_201.npy
#
# Load #points: 231  from output/fireD_headsM/measured/coord_202.npy
#
# Load #points: 319  from output/fireD_headsM/measured/coord_203.npy
#
# Load #points: 267  from output/fireD_headsM/measured/coord_204.npy
#
# Load #points: 376  from output/fireD_headsM/measured/coord_205.npy
#
# Load #points: 376  from output/fireD_headsM/measured/coord_206.npy
#
# Load #points: 263  from output/fireD_headsM/measured/coord_207.npy
#
# Load #points: 277  from output/fireD_headsM/measured/coord_208.npy
#
# Load #points: 292  from output/fireD_headsM/measured/coord_209.npy
#
# Load #points: 369  from output/fireD_headsM/measured/coord_210.npy
#
# Load #points: 470  from output/fireD_headsM/measured/coord_211.npy
#
# Load #points: 470  from output/fireD_headsM/measured/coord_212.npy
#
# Load #points: 489  from output/fireD_headsM/measured/coord_213.npy
#
# Load #points: 531  from output/fireD_headsM/measured/coord_214.npy
#
# Load #points: 595  from output/fireD_headsM/measured/coord_215.npy
#
# Load #points: 571  from output/fireD_headsM/measured/coord_216.npy
#
# Load #points: 500  from output/fireD_headsM/measured/coord_217.npy
#
# Load #points: 500  from output/fireD_headsM/measured/coord_218.npy
#
# Load #points: 475  from output/fireD_headsM/measured/coord_219.npy
#
# Load #points: 453  from output/fireD_headsM/measured/coord_220.npy
#
# Load #points: 447  from output/fireD_headsM/measured/coord_221.npy
#
# Load #points: 447  from output/fireD_headsM/measured/coord_222.npy
#
# Load #points: 458  from output/fireD_headsM/measured/coord_223.npy
#
# Load #points: 449  from output/fireD_headsM/measured/coord_224.npy
#
# Load #points: 344  from output/fireD_headsM/measured/coord_225.npy
#
# Load #points: 358  from output/fireD_headsM/measured/coord_226.npy
#
# Load #points: 358  from output/fireD_headsM/measured/coord_227.npy
#
# Load #points: 406  from output/fireD_headsM/measured/coord_228.npy
#
# Load #points: 299  from output/fireD_headsM/measured/coord_229.npy
#
# Load #points: 289  from output/fireD_headsM/measured/coord_230.npy
#
# Load #points: 303  from output/fireD_headsM/measured/coord_231.npy
#
# Load #points: 303  from output/fireD_headsM/measured/coord_232.npy
#
# Load #points: 303  from output/fireD_headsM/measured/coord_233.npy
#
# Load #points: 261  from output/fireD_headsM/measured/coord_234.npy
#
# Load #points: 282  from output/fireD_headsM/measured/coord_235.npy
#
# Load #points: 333  from output/fireD_headsM/measured/coord_236.npy
#
# Load #points: 344  from output/fireD_headsM/measured/coord_237.npy
#
# Load #points: 344  from output/fireD_headsM/measured/coord_238.npy
#
# Load #points: 382  from output/fireD_headsM/measured/coord_239.npy
#
# Load #points: 402  from output/fireD_headsM/measured/coord_240.npy
#
# Load #points: 358  from output/fireD_headsM/measured/coord_241.npy
#
# Load #points: 327  from output/fireD_headsM/measured/coord_242.npy
#
# Load #points: 335  from output/fireD_headsM/measured/coord_243.npy
#
# Load #points: 335  from output/fireD_headsM/measured/coord_244.npy
#
# Load #points: 398  from output/fireD_headsM/measured/coord_245.npy
#
# Load #points: 463  from output/fireD_headsM/measured/coord_246.npy
#
# Load #points: 390  from output/fireD_headsM/measured/coord_247.npy
#
# Load #points: 413  from output/fireD_headsM/measured/coord_248.npy
#
# Load #points: 413  from output/fireD_headsM/measured/coord_249.npy
#
# Load #points: 332  from output/fireD_headsM/measured/coord_250.npy
#
# Load #points: 273  from output/fireD_headsM/measured/coord_251.npy
#
# Load #points: 407  from output/fireD_headsM/measured/coord_252.npy
#
# Load #points: 342  from output/fireD_headsM/measured/coord_253.npy
#
# Load #points: 424  from output/fireD_headsM/measured/coord_254.npy
#
# Load #points: 424  from output/fireD_headsM/measured/coord_255.npy
#
# Load #points: 291  from output/fireD_headsM/measured/coord_256.npy
#
# Load #points: 281  from output/fireD_headsM/measured/coord_257.npy
#
# Load #points: 297  from output/fireD_headsM/measured/coord_258.npy
#
# Load #points: 281  from output/fireD_headsM/measured/coord_259.npy
#
# Load #points: 286  from output/fireD_headsM/measured/coord_260.npy
#
# Load #points: 286  from output/fireD_headsM/measured/coord_261.npy
#
# Load #points: 220  from output/fireD_headsM/measured/coord_262.npy
#
# Load #points: 242  from output/fireD_headsM/measured/coord_263.npy
#
# Load #points: 233  from output/fireD_headsM/measured/coord_264.npy
#
# Load #points: 233  from output/fireD_headsM/measured/coord_265.npy
#
# Load #points: 181  from output/fireD_headsM/measured/coord_266.npy
#
# Load #points: 199  from output/fireD_headsM/measured/coord_267.npy
#
# Load #points: 186  from output/fireD_headsM/measured/coord_268.npy
#
# Load #points: 200  from output/fireD_headsM/measured/coord_269.npy
#
# Load #points: 200  from output/fireD_headsM/measured/coord_270.npy
#
# Load #points: 179  from output/fireD_headsM/measured/coord_271.npy
#
# Load #points: 224  from output/fireD_headsM/measured/coord_272.npy
#
# Load #points: 214  from output/fireD_headsM/measured/coord_273.npy
#
# Load #points: 223  from output/fireD_headsM/measured/coord_274.npy
#
# Load #points: 223  from output/fireD_headsM/measured/coord_275.npy
#
# Load #points: 227  from output/fireD_headsM/measured/coord_276.npy
#
# Load #points: 206  from output/fireD_headsM/measured/coord_277.npy
#
# Load #points: 264  from output/fireD_headsM/measured/coord_278.npy
#
# Load #points: 214  from output/fireD_headsM/measured/coord_279.npy
#
# Load #points: 214  from output/fireD_headsM/measured/coord_280.npy
#
# Load #points: 190  from output/fireD_headsM/measured/coord_281.npy
#
# Load #points: 262  from output/fireD_headsM/measured/coord_282.npy
#
# Load #points: 304  from output/fireD_headsM/measured/coord_283.npy
#
# Load #points: 304  from output/fireD_headsM/measured/coord_284.npy
#
# Load #points: 304  from output/fireD_headsM/measured/coord_285.npy
#
# Load #points: 277  from output/fireD_headsM/measured/coord_286.npy
#
# Load #points: 305  from output/fireD_headsM/measured/coord_287.npy
#
# Load #points: 299  from output/fireD_headsM/measured/coord_288.npy
#
# Load #points: 326  from output/fireD_headsM/measured/coord_289.npy
#
# Load #points: 292  from output/fireD_headsM/measured/coord_290.npy
#
# Load #points: 292  from output/fireD_headsM/measured/coord_291.npy
#
# Load #points: 256  from output/fireD_headsM/measured/coord_292.npy
#
# Load #points: 246  from output/fireD_headsM/measured/coord_293.npy
#
# Load #points: 317  from output/fireD_headsM/measured/coord_294.npy
#
# Load #points: 303  from output/fireD_headsM/measured/coord_295.npy
#
# Load #points: 274  from output/fireD_headsM/measured/coord_296.npy
#
# Load #points: 259  from output/fireD_headsM/measured/coord_297.npy
#
# Load #points: 259  from output/fireD_headsM/measured/coord_298.npy
#
# Load #points: 274  from output/fireD_headsM/measured/coord_299.npy
#
# Load #points: 305  from output/fireD_headsM/measured/coord_300.npy
#
# Load #points: 291  from output/fireD_headsM/measured/coord_301.npy
#
# Load #points: 327  from output/fireD_headsM/measured/coord_302.npy
#
# Load #points: 345  from output/fireD_headsM/measured/coord_303.npy
#
# Load #points: 359  from output/fireD_headsM/measured/coord_304.npy
#
# Load #points: 359  from output/fireD_headsM/measured/coord_305.npy
#
# Load #points: 307  from output/fireD_headsM/measured/coord_306.npy
#
# Load #points: 363  from output/fireD_headsM/measured/coord_307.npy
#
# Load #points: 415  from output/fireD_headsM/measured/coord_308.npy
#
# Load #points: 317  from output/fireD_headsM/measured/coord_309.npy
#
# Load #points: 370  from output/fireD_headsM/measured/coord_310.npy
#
# Load #points: 349  from output/fireD_headsM/measured/coord_311.npy
#
# Load #points: 393  from output/fireD_headsM/measured/coord_312.npy
#
# Load #points: 393  from output/fireD_headsM/measured/coord_313.npy
#
# Load #points: 418  from output/fireD_headsM/measured/coord_314.npy
#
# Load #points: 377  from output/fireD_headsM/measured/coord_315.npy
#
# Load #points: 333  from output/fireD_headsM/measured/coord_316.npy
#
# Load #points: 366  from output/fireD_headsM/measured/coord_317.npy
#
# Load #points: 376  from output/fireD_headsM/measured/coord_318.npy
#
# Load #points: 313  from output/fireD_headsM/measured/coord_319.npy
#
# Load #points: 330  from output/fireD_headsM/measured/coord_320.npy
#
# Load #points: 355  from output/fireD_headsM/measured/coord_321.npy
#
# Load #points: 343  from output/fireD_headsM/measured/coord_322.npy
#
# Load #points: 390  from output/fireD_headsM/measured/coord_323.npy
#
# Load #points: 383  from output/fireD_headsM/measured/coord_324.npy
#
# Load #points: 398  from output/fireD_headsM/measured/coord_325.npy
#
# Load #points: 417  from output/fireD_headsM/measured/coord_326.npy
#
# Load #points: 446  from output/fireD_headsM/measured/coord_327.npy
#
# Load #points: 489  from output/fireD_headsM/measured/coord_328.npy
#
# Load #points: 432  from output/fireD_headsM/measured/coord_329.npy
#
# Load #points: 432  from output/fireD_headsM/measured/coord_330.npy
#
# Load #points: 479  from output/fireD_headsM/measured/coord_331.npy
#
# Load #points: 545  from output/fireD_headsM/measured/coord_332.npy
#
# Load #points: 515  from output/fireD_headsM/measured/coord_333.npy
#
# Load #points: 597  from output/fireD_headsM/measured/coord_334.npy
#
# Load #points: 514  from output/fireD_headsM/measured/coord_335.npy
#
# Load #points: 563  from output/fireD_headsM/measured/coord_336.npy
#
# Load #points: 501  from output/fireD_headsM/measured/coord_337.npy
#
# Load #points: 593  from output/fireD_headsM/measured/coord_338.npy
#
# Load #points: 575  from output/fireD_headsM/measured/coord_339.npy
#
# Load #points: 540  from output/fireD_headsM/measured/coord_340.npy
#
# Load #points: 529  from output/fireD_headsM/measured/coord_341.npy
#
# Load #points: 571  from output/fireD_headsM/measured/coord_342.npy
#
# Load #points: 483  from output/fireD_headsM/measured/coord_343.npy
#
# Load #points: 465  from output/fireD_headsM/measured/coord_344.npy
#
# Load #points: 544  from output/fireD_headsM/measured/coord_345.npy
#
# Load #points: 422  from output/fireD_headsM/measured/coord_346.npy
#
# Load #points: 444  from output/fireD_headsM/measured/coord_347.npy
#
# Load #points: 455  from output/fireD_headsM/measured/coord_348.npy
#
# Load #points: 476  from output/fireD_headsM/measured/coord_349.npy
#
# Load #points: 444  from output/fireD_headsM/measured/coord_350.npy
#
# Load #points: 484  from output/fireD_headsM/measured/coord_351.npy
#
# Load #points: 508  from output/fireD_headsM/measured/coord_352.npy
#
# Load #points: 521  from output/fireD_headsM/measured/coord_353.npy
#
# Load #points: 515  from output/fireD_headsM/measured/coord_354.npy
#
# Load #points: 474  from output/fireD_headsM/measured/coord_355.npy
#
# Load #points: 530  from output/fireD_headsM/measured/coord_356.npy
#
# Load #points: 490  from output/fireD_headsM/measured/coord_357.npy
#
# Load #points: 467  from output/fireD_headsM/measured/coord_358.npy
#
# Load #points: 455  from output/fireD_headsM/measured/coord_359.npy
#
# Load #points: 426  from output/fireD_headsM/measured/coord_360.npy
#
# Load #points: 381  from output/fireD_headsM/measured/coord_361.npy
#
# Load #points: 373  from output/fireD_headsM/measured/coord_362.npy
#
# Load #points: 378  from output/fireD_headsM/measured/coord_363.npy
#
# Load #points: 345  from output/fireD_headsM/measured/coord_364.npy
#
# Load #points: 311  from output/fireD_headsM/measured/coord_365.npy
#
# Load #points: 260  from output/fireD_headsM/measured/coord_366.npy
#
# Load #points: 246  from output/fireD_headsM/measured/coord_367.npy
#
# Load #points: 234  from output/fireD_headsM/measured/coord_368.npy
#
# Load #points: 272  from output/fireD_headsM/measured/coord_369.npy
#
# Load #points: 215  from output/fireD_headsM/measured/coord_370.npy
#
# Load #points: 292  from output/fireD_headsM/measured/coord_371.npy
#
# Load #points: 268  from output/fireD_headsM/measured/coord_372.npy
#
# Load #points: 348  from output/fireD_headsM/measured/coord_373.npy
#
# Load #points: 196  from output/fireD_headsM/measured/coord_374.npy
#
# Load #points: 148  from output/fireD_headsM/measured/coord_375.npy
#
# Load #points: 237  from output/fireD_headsM/measured/coord_376.npy
#
# Load #points: 274  from output/fireD_headsM/measured/coord_377.npy
#
# Load #points: 275  from output/fireD_headsM/measured/coord_378.npy
#
# Load #points: 313  from output/fireD_headsM/measured/coord_379.npy
#
# Load #points: 236  from output/fireD_headsM/measured/coord_380.npy
#
# Load #points: 323  from output/fireD_headsM/measured/coord_381.npy
#
# Load #points: 337  from output/fireD_headsM/measured/coord_382.npy
#
# Load #points: 259  from output/fireD_headsM/measured/coord_383.npy
#
# Load #points: 235  from output/fireD_headsM/measured/coord_384.npy
#
# Load #points: 217  from output/fireD_headsM/measured/coord_385.npy
#
# Load #points: 173  from output/fireD_headsM/measured/coord_386.npy
#
# Load #points: 220  from output/fireD_headsM/measured/coord_387.npy
#
# Load #points: 228  from output/fireD_headsM/measured/coord_388.npy
#
# Load #points: 205  from output/fireD_headsM/measured/coord_389.npy
#
# Load #points: 225  from output/fireD_headsM/measured/coord_390.npy
#
# Load #points: 254  from output/fireD_headsM/measured/coord_391.npy
#
# Load #points: 310  from output/fireD_headsM/measured/coord_392.npy
#
# Load #points: 288  from output/fireD_headsM/measured/coord_393.npy
#
# Load #points: 385  from output/fireD_headsM/measured/coord_394.npy
#
# Load #points: 344  from output/fireD_headsM/measured/coord_395.npy
#
# Load #points: 322  from output/fireD_headsM/measured/coord_396.npy
#
# Load #points: 312  from output/fireD_headsM/measured/coord_397.npy
#
# Load #points: 352  from output/fireD_headsM/measured/coord_398.npy
#
# Load #points: 319  from output/fireD_headsM/measured/coord_399.npy
#
# Load #points: 301  from output/fireD_headsM/measured/coord_400.npy
#
# Load #points: 278  from output/fireD_headsM/measured/coord_401.npy
#
# Load #points: 280  from output/fireD_headsM/measured/coord_402.npy
#
# Load #points: 275  from output/fireD_headsM/measured/coord_403.npy
#
# Load #points: 285  from output/fireD_headsM/measured/coord_404.npy
#
# Load #points: 306  from output/fireD_headsM/measured/coord_405.npy
#
# Load #points: 286  from output/fireD_headsM/measured/coord_406.npy
#
# Load #points: 276  from output/fireD_headsM/measured/coord_407.npy
#
# Load #points: 298  from output/fireD_headsM/measured/coord_408.npy
#
# Load #points: 277  from output/fireD_headsM/measured/coord_409.npy
#
# Load #points: 254  from output/fireD_headsM/measured/coord_410.npy
#
# Load #points: 255  from output/fireD_headsM/measured/coord_411.npy
#
# Load #points: 238  from output/fireD_headsM/measured/coord_412.npy
#
# Load #points: 233  from output/fireD_headsM/measured/coord_413.npy
#
# Load #points: 242  from output/fireD_headsM/measured/coord_414.npy
#
# Load #points: 234  from output/fireD_headsM/measured/coord_415.npy
#
# Load #points: 260  from output/fireD_headsM/measured/coord_416.npy
#
# Load #points: 248  from output/fireD_headsM/measured/coord_417.npy
#
# Load #points: 256  from output/fireD_headsM/measured/coord_418.npy
#
# Load #points: 261  from output/fireD_headsM/measured/coord_419.npy
#
# Load #points: 265  from output/fireD_headsM/measured/coord_420.npy
#
# Load #points: 262  from output/fireD_headsM/measured/coord_421.npy
#
# Load #points: 300  from output/fireD_headsM/measured/coord_422.npy
#
# Load #points: 298  from output/fireD_headsM/measured/coord_423.npy
#
# Load #points: 278  from output/fireD_headsM/measured/coord_424.npy
#
# Load #points: 269  from output/fireD_headsM/measured/coord_425.npy
#
# Load #points: 313  from output/fireD_headsM/measured/coord_426.npy
#
# Load #points: 329  from output/fireD_headsM/measured/coord_427.npy
#
# Load #points: 316  from output/fireD_headsM/measured/coord_428.npy
#
# Load #points: 323  from output/fireD_headsM/measured/coord_429.npy
#
# Load #points: 315  from output/fireD_headsM/measured/coord_430.npy
#
# Load #points: 318  from output/fireD_headsM/measured/coord_431.npy
#
# Load #points: 307  from output/fireD_headsM/measured/coord_432.npy
#
# Load #points: 279  from output/fireD_headsM/measured/coord_433.npy
#
# Load #points: 332  from output/fireD_headsM/measured/coord_434.npy
#
# Load #points: 296  from output/fireD_headsM/measured/coord_435.npy
#
# Load #points: 238  from output/fireD_headsM/measured/coord_436.npy
#
# Load #points: 270  from output/fireD_headsM/measured/coord_437.npy
#
# Load #points: 243  from output/fireD_headsM/measured/coord_438.npy
#
# Load #points: 286  from output/fireD_headsM/measured/coord_439.npy
#
# Load #points: 251  from output/fireD_headsM/measured/coord_440.npy
#
# Load #points: 271  from output/fireD_headsM/measured/coord_441.npy
#
# Load #points: 249  from output/fireD_headsM/measured/coord_442.npy
#
# Load #points: 224  from output/fireD_headsM/measured/coord_443.npy
#
# Load #points: 221  from output/fireD_headsM/measured/coord_444.npy
#
# Load #points: 241  from output/fireD_headsM/measured/coord_445.npy
#
# Load #points: 246  from output/fireD_headsM/measured/coord_446.npy
#
# Load #points: 237  from output/fireD_headsM/measured/coord_447.npy
#
# Load #points: 234  from output/fireD_headsM/measured/coord_448.npy
#
# Load #points: 266  from output/fireD_headsM/measured/coord_449.npy
#
# Load #points: 274  from output/fireD_headsM/measured/coord_450.npy
#
# Load #points: 248  from output/fireD_headsM/measured/coord_451.npy
#
# Load #points: 259  from output/fireD_headsM/measured/coord_452.npy
#
# Load #points: 291  from output/fireD_headsM/measured/coord_453.npy
#
# Load #points: 305  from output/fireD_headsM/measured/coord_454.npy
#
# Load #points: 350  from output/fireD_headsM/measured/coord_455.npy
#
# Load #points: 354  from output/fireD_headsM/measured/coord_456.npy
#
# Load #points: 378  from output/fireD_headsM/measured/coord_457.npy
#
# Load #points: 375  from output/fireD_headsM/measured/coord_458.npy
#
# Load #points: 417  from output/fireD_headsM/measured/coord_459.npy
#
# Load #points: 458  from output/fireD_headsM/measured/coord_460.npy
#
# Load #points: 474  from output/fireD_headsM/measured/coord_461.npy
#
# Load #points: 460  from output/fireD_headsM/measured/coord_462.npy
#
# Load #points: 503  from output/fireD_headsM/measured/coord_463.npy
#
# Load #points: 510  from output/fireD_headsM/measured/coord_464.npy
#
# Load #points: 486  from output/fireD_headsM/measured/coord_465.npy
#
# Load #points: 512  from output/fireD_headsM/measured/coord_466.npy
#
# Load #points: 492  from output/fireD_headsM/measured/coord_467.npy
#
# Load #points: 513  from output/fireD_headsM/measured/coord_468.npy
#
# Load #points: 524  from output/fireD_headsM/measured/coord_469.npy
#
# Load #points: 514  from output/fireD_headsM/measured/coord_470.npy
#
# Load #points: 542  from output/fireD_headsM/measured/coord_471.npy
#
# Load #points: 560  from output/fireD_headsM/measured/coord_472.npy
#
# Load #points: 577  from output/fireD_headsM/measured/coord_473.npy
#
# Load #points: 599  from output/fireD_headsM/measured/coord_474.npy
#
# Load #points: 623  from output/fireD_headsM/measured/coord_475.npy
#
# Load #points: 626  from output/fireD_headsM/measured/coord_476.npy
#
# Load #points: 684  from output/fireD_headsM/measured/coord_477.npy
#
# Load #points: 684  from output/fireD_headsM/measured/coord_478.npy
#
# Load #points: 667  from output/fireD_headsM/measured/coord_479.npy
#
# Load #points: 738  from output/fireD_headsM/measured/coord_480.npy
#
# Load #points: 735  from output/fireD_headsM/measured/coord_481.npy
#
# Load #points: 726  from output/fireD_headsM/measured/coord_482.npy
#
# Load #points: 752  from output/fireD_headsM/measured/coord_483.npy
#
# Load #points: 801  from output/fireD_headsM/measured/coord_484.npy
#
# Load #points: 792  from output/fireD_headsM/measured/coord_485.npy
#
# Load #points: 784  from output/fireD_headsM/measured/coord_486.npy
#
# Load #points: 798  from output/fireD_headsM/measured/coord_487.npy
#
# Load #points: 854  from output/fireD_headsM/measured/coord_488.npy
#
# Load #points: 857  from output/fireD_headsM/measured/coord_489.npy
#
# Load #points: 897  from output/fireD_headsM/measured/coord_490.npy
#
# Load #points: 914  from output/fireD_headsM/measured/coord_491.npy
#
# Load #points: 888  from output/fireD_headsM/measured/coord_492.npy
#
# Load #points: 866  from output/fireD_headsM/measured/coord_493.npy
#
# Load #points: 840  from output/fireD_headsM/measured/coord_494.npy
#
# Load #points: 811  from output/fireD_headsM/measured/coord_495.npy
#
# Load #points: 832  from output/fireD_headsM/measured/coord_496.npy
#
# Load #points: 823  from output/fireD_headsM/measured/coord_497.npy
#
# Load #points: 776  from output/fireD_headsM/measured/coord_498.npy
#
# Load #points: 739  from output/fireD_headsM/measured/coord_499.npy
#
# Load #points: 718  from output/fireD_headsM/measured/coord_500.npy
#
# Load #points: 703  from output/fireD_headsM/measured/coord_501.npy
#
# Load #points: 635  from output/fireD_headsM/measured/coord_502.npy
#
# Load #points: 640  from output/fireD_headsM/measured/coord_503.npy
#
# Load #points: 586  from output/fireD_headsM/measured/coord_504.npy
#
# Load #points: 527  from output/fireD_headsM/measured/coord_505.npy
#
# Load #points: 441  from output/fireD_headsM/measured/coord_506.npy
#
# Load #points: 458  from output/fireD_headsM/measured/coord_507.npy
#
# Load #points: 449  from output/fireD_headsM/measured/coord_508.npy
#
# Load #points: 429  from output/fireD_headsM/measured/coord_509.npy
#
# Load #points: 495  from output/fireD_headsM/measured/coord_510.npy
#
# Load #points: 450  from output/fireD_headsM/measured/coord_511.npy
#
# Load #points: 446  from output/fireD_headsM/measured/coord_512.npy
#
# Load #points: 489  from output/fireD_headsM/measured/coord_513.npy
#
# Load #points: 469  from output/fireD_headsM/measured/coord_514.npy
#
# Load #points: 459  from output/fireD_headsM/measured/coord_515.npy
#
# Load #points: 464  from output/fireD_headsM/measured/coord_516.npy
#
# Load #points: 367  from output/fireD_headsM/measured/coord_517.npy
#
# Load #points: 382  from output/fireD_headsM/measured/coord_518.npy
#
# Load #points: 442  from output/fireD_headsM/measured/coord_519.npy
#
# Load #points: 445  from output/fireD_headsM/measured/coord_520.npy
#
# Load #points: 433  from output/fireD_headsM/measured/coord_521.npy
#
# Load #points: 415  from output/fireD_headsM/measured/coord_522.npy
#
# Load #points: 431  from output/fireD_headsM/measured/coord_523.npy
#
# Load #points: 478  from output/fireD_headsM/measured/coord_524.npy
#
# Load #points: 481  from output/fireD_headsM/measured/coord_525.npy
#
# Load #points: 444  from output/fireD_headsM/measured/coord_526.npy
#
# Load #points: 435  from output/fireD_headsM/measured/coord_527.npy
#
# Load #points: 400  from output/fireD_headsM/measured/coord_528.npy
#
# Load #points: 418  from output/fireD_headsM/measured/coord_529.npy
#
# Load #points: 431  from output/fireD_headsM/measured/coord_530.npy
#
# Load #points: 489  from output/fireD_headsM/measured/coord_531.npy
#
# Load #points: 437  from output/fireD_headsM/measured/coord_532.npy
#
# Load #points: 478  from output/fireD_headsM/measured/coord_533.npy
#
# Load #points: 452  from output/fireD_headsM/measured/coord_534.npy
#
# Load #points: 400  from output/fireD_headsM/measured/coord_535.npy
#
# Load #points: 448  from output/fireD_headsM/measured/coord_536.npy
#
# Load #points: 439  from output/fireD_headsM/measured/coord_537.npy
#
# Load #points: 442  from output/fireD_headsM/measured/coord_538.npy
#
# Load #points: 407  from output/fireD_headsM/measured/coord_539.npy
#
# Load #points: 434  from output/fireD_headsM/measured/coord_540.npy
#
# Load #points: 406  from output/fireD_headsM/measured/coord_541.npy
#
# Load #points: 297  from output/fireD_headsM/measured/coord_542.npy
#
# Load #points: 359  from output/fireD_headsM/measured/coord_543.npy
#
# Load #points: 432  from output/fireD_headsM/measured/coord_544.npy
#
# Load #points: 517  from output/fireD_headsM/measured/coord_545.npy
#
# Load #points: 493  from output/fireD_headsM/measured/coord_546.npy
#
# Load #points: 481  from output/fireD_headsM/measured/coord_547.npy
#
# Load #points: 521  from output/fireD_headsM/measured/coord_548.npy
#
# Load #points: 459  from output/fireD_headsM/measured/coord_549.npy
#
# Load #points: 458  from output/fireD_headsM/measured/coord_550.npy
#
# Load #points: 517  from output/fireD_headsM/measured/coord_551.npy
#
# Load #points: 459  from output/fireD_headsM/measured/coord_552.npy
#
# Load #points: 463  from output/fireD_headsM/measured/coord_553.npy
#
# Load #points: 387  from output/fireD_headsM/measured/coord_554.npy
#
# Load #points: 385  from output/fireD_headsM/measured/coord_555.npy
#
# Load #points: 430  from output/fireD_headsM/measured/coord_556.npy
#
# Load #points: 558  from output/fireD_headsM/measured/coord_557.npy
#
# Load #points: 417  from output/fireD_headsM/measured/coord_558.npy
#
# Load #points: 311  from output/fireD_headsM/measured/coord_559.npy
#
# Load #points: 406  from output/fireD_headsM/measured/coord_560.npy
#
# Load #points: 315  from output/fireD_headsM/measured/coord_561.npy
#
# Load #points: 320  from output/fireD_headsM/measured/coord_562.npy
#
# Load #points: 351  from output/fireD_headsM/measured/coord_563.npy
#
# Load #points: 293  from output/fireD_headsM/measured/coord_564.npy
#
# Load #points: 241  from output/fireD_headsM/measured/coord_565.npy
#
# Load #points: 399  from output/fireD_headsM/measured/coord_566.npy
#
# Load #points: 405  from output/fireD_headsM/measured/coord_567.npy
#
# Load #points: 378  from output/fireD_headsM/measured/coord_568.npy
#
# Load #points: 645  from output/fireD_headsM/measured/coord_569.npy
#
# Load #points: 403  from output/fireD_headsM/measured/coord_570.npy
#
# Load #points: 492  from output/fireD_headsM/measured/coord_571.npy
#
# Load #points: 655  from output/fireD_headsM/measured/coord_572.npy
#
# Load #points: 473  from output/fireD_headsM/measured/coord_573.npy
#
# Load #points: 395  from output/fireD_headsM/measured/coord_574.npy
#
# Load #points: 438  from output/fireD_headsM/measured/coord_575.npy
#
# Load #points: 436  from output/fireD_headsM/measured/coord_576.npy
#
# Load #points: 369  from output/fireD_headsM/measured/coord_577.npy
#
# Load #points: 413  from output/fireD_headsM/measured/coord_578.npy
#
# Load #points: 368  from output/fireD_headsM/measured/coord_579.npy
#
# Load #points: 380  from output/fireD_headsM/measured/coord_580.npy
#
# Load #points: 356  from output/fireD_headsM/measured/coord_581.npy
#
# Load #points: 443  from output/fireD_headsM/measured/coord_582.npy
#
# Load #points: 347  from output/fireD_headsM/measured/coord_583.npy
#
# Load #points: 438  from output/fireD_headsM/measured/coord_584.npy
#
# Load #points: 434  from output/fireD_headsM/measured/coord_585.npy
#
# Load #points: 514  from output/fireD_headsM/measured/coord_586.npy
#
# Load #points: 529  from output/fireD_headsM/measured/coord_587.npy
#
# Load #points: 392  from output/fireD_headsM/measured/coord_588.npy
#
# Load #points: 271  from output/fireD_headsM/measured/coord_589.npy
#
# Load #points: 383  from output/fireD_headsM/measured/coord_590.npy
#
# Load #points: 395  from output/fireD_headsM/measured/coord_591.npy
#
# Load #points: 358  from output/fireD_headsM/measured/coord_592.npy
#
# Load #points: 348  from output/fireD_headsM/measured/coord_593.npy
#
# Load #points: 222  from output/fireD_headsM/measured/coord_594.npy
#
# Load #points: 263  from output/fireD_headsM/measured/coord_595.npy
#
# Load #points: 291  from output/fireD_headsM/measured/coord_596.npy
#
# Load #points: 271  from output/fireD_headsM/measured/coord_597.npy
#
# Load #points: 257  from output/fireD_headsM/measured/coord_598.npy
#
# Load #points: 254  from output/fireD_headsM/measured/coord_599.npy
#
# Load #points: 269  from output/fireD_headsM/measured/coord_600.npy
#
# Load #points: 272  from output/fireD_headsM/measured/coord_601.npy
#
# Load #points: 271  from output/fireD_headsM/measured/coord_602.npy
#
# Load #points: 298  from output/fireD_headsM/measured/coord_603.npy
#
# Load #points: 270  from output/fireD_headsM/measured/coord_604.npy
#
# Load #points: 328  from output/fireD_headsM/measured/coord_605.npy
#
# Load #points: 301  from output/fireD_headsM/measured/coord_606.npy
#
# Load #points: 287  from output/fireD_headsM/measured/coord_607.npy
#
# Load #points: 268  from output/fireD_headsM/measured/coord_608.npy
#
# Load #points: 239  from output/fireD_headsM/measured/coord_609.npy
#
# Load #points: 263  from output/fireD_headsM/measured/coord_610.npy
#
# Load #points: 278  from output/fireD_headsM/measured/coord_611.npy
#
# Load #points: 241  from output/fireD_headsM/measured/coord_612.npy
#
# Load #points: 380  from output/fireD_headsM/measured/coord_613.npy
#
# Load #points: 286  from output/fireD_headsM/measured/coord_614.npy
#
# Load #points: 272  from output/fireD_headsM/measured/coord_615.npy
#
# Load #points: 387  from output/fireD_headsM/measured/coord_616.npy
#
# Load #points: 444  from output/fireD_headsM/measured/coord_617.npy
#
# Load #points: 467  from output/fireD_headsM/measured/coord_618.npy
#
# Load #points: 456  from output/fireD_headsM/measured/coord_619.npy
#
# Load #points: 392  from output/fireD_headsM/measured/coord_620.npy
#
# Load #points: 364  from output/fireD_headsM/measured/coord_621.npy
#
# Load #points: 398  from output/fireD_headsM/measured/coord_622.npy
#
# Load #points: 327  from output/fireD_headsM/measured/coord_623.npy
#
# Load #points: 355  from output/fireD_headsM/measured/coord_624.npy
#
# Load #points: 365  from output/fireD_headsM/measured/coord_625.npy
#
# Load #points: 335  from output/fireD_headsM/measured/coord_626.npy
#
# Load #points: 344  from output/fireD_headsM/measured/coord_627.npy
#
# Load #points: 337  from output/fireD_headsM/measured/coord_628.npy
#
# Load #points: 345  from output/fireD_headsM/measured/coord_629.npy
#
# Load #points: 364  from output/fireD_headsM/measured/coord_630.npy
#
# Load #points: 380  from output/fireD_headsM/measured/coord_631.npy
#
# Load #points: 377  from output/fireD_headsM/measured/coord_632.npy
#
# Load #points: 396  from output/fireD_headsM/measured/coord_633.npy
#
# Load #points: 414  from output/fireD_headsM/measured/coord_634.npy
#
# Load #points: 475  from output/fireD_headsM/measured/coord_635.npy
#
# Load #points: 480  from output/fireD_headsM/measured/coord_636.npy
#
# Load #points: 515  from output/fireD_headsM/measured/coord_637.npy
#
# Load #points: 522  from output/fireD_headsM/measured/coord_638.npy
#
# Load #points: 498  from output/fireD_headsM/measured/coord_639.npy
#
# Load #points: 566  from output/fireD_headsM/measured/coord_640.npy
#
# Load #points: 574  from output/fireD_headsM/measured/coord_641.npy
#
# Load #points: 605  from output/fireD_headsM/measured/coord_642.npy
#
# Load #points: 584  from output/fireD_headsM/measured/coord_643.npy
#
# Load #points: 592  from output/fireD_headsM/measured/coord_644.npy
#
# Load #points: 560  from output/fireD_headsM/measured/coord_645.npy
#
# Load #points: 608  from output/fireD_headsM/measured/coord_646.npy
#
# Load #points: 556  from output/fireD_headsM/measured/coord_647.npy
#
# Load #points: 589  from output/fireD_headsM/measured/coord_648.npy
#
# Load #points: 513  from output/fireD_headsM/measured/coord_649.npy
#
# Load #points: 560  from output/fireD_headsM/measured/coord_650.npy
#
# Load #points: 540  from output/fireD_headsM/measured/coord_651.npy
#
# Load #points: 583  from output/fireD_headsM/measured/coord_652.npy
#
# Load #points: 619  from output/fireD_headsM/measured/coord_653.npy
#
# Load #points: 582  from output/fireD_headsM/measured/coord_654.npy
#
# Load #points: 606  from output/fireD_headsM/measured/coord_655.npy
#
# Load #points: 595  from output/fireD_headsM/measured/coord_656.npy
#
# Load #points: 579  from output/fireD_headsM/measured/coord_657.npy
#
# Load #points: 542  from output/fireD_headsM/measured/coord_658.npy
#
# Load #points: 528  from output/fireD_headsM/measured/coord_659.npy
#
# Load #points: 500  from output/fireD_headsM/measured/coord_660.npy
#
# Load #points: 502  from output/fireD_headsM/measured/coord_661.npy
#
# Load #points: 456  from output/fireD_headsM/measured/coord_662.npy
#
# Load #points: 468  from output/fireD_headsM/measured/coord_663.npy
#
# Load #points: 461  from output/fireD_headsM/measured/coord_664.npy
#
# Load #points: 413  from output/fireD_headsM/measured/coord_665.npy
#
# Load #points: 420  from output/fireD_headsM/measured/coord_666.npy
#
# Load #points: 386  from output/fireD_headsM/measured/coord_667.npy
#
# Load #points: 420  from output/fireD_headsM/measured/coord_668.npy
#
# Load #points: 362  from output/fireD_headsM/measured/coord_669.npy
#
# Load #points: 389  from output/fireD_headsM/measured/coord_670.npy
#
# Load #points: 394  from output/fireD_headsM/measured/coord_671.npy
#
# Load #points: 387  from output/fireD_headsM/measured/coord_672.npy
#
# Load #points: 392  from output/fireD_headsM/measured/coord_673.npy
#
# Load #points: 375  from output/fireD_headsM/measured/coord_674.npy
#
# Load #points: 405  from output/fireD_headsM/measured/coord_675.npy
#
# Load #points: 413  from output/fireD_headsM/measured/coord_676.npy
#
# Load #points: 395  from output/fireD_headsM/measured/coord_677.npy
#
# Load #points: 361  from output/fireD_headsM/measured/coord_678.npy
#
# Load #points: 381  from output/fireD_headsM/measured/coord_679.npy
#
# Load #points: 385  from output/fireD_headsM/measured/coord_680.npy
#
# Load #points: 396  from output/fireD_headsM/measured/coord_681.npy
#
# Load #points: 403  from output/fireD_headsM/measured/coord_682.npy
#
# Load #points: 378  from output/fireD_headsM/measured/coord_683.npy
#
# Load #points: 369  from output/fireD_headsM/measured/coord_684.npy
#
# Load #points: 372  from output/fireD_headsM/measured/coord_685.npy
#
# Load #points: 365  from output/fireD_headsM/measured/coord_686.npy
#
# Load #points: 364  from output/fireD_headsM/measured/coord_687.npy
#
# Load #points: 340  from output/fireD_headsM/measured/coord_688.npy
#
# Load #points: 345  from output/fireD_headsM/measured/coord_689.npy
#
# Load #points: 363  from output/fireD_headsM/measured/coord_690.npy
#
# Load #points: 372  from output/fireD_headsM/measured/coord_691.npy
#
# Load #points: 360  from output/fireD_headsM/measured/coord_692.npy
#
# Load #points: 377  from output/fireD_headsM/measured/coord_693.npy
#
# Load #points: 399  from output/fireD_headsM/measured/coord_694.npy
#
# Load #points: 392  from output/fireD_headsM/measured/coord_695.npy
#
# Load #points: 388  from output/fireD_headsM/measured/coord_696.npy
#
# Load #points: 389  from output/fireD_headsM/measured/coord_697.npy
#
# Load #points: 393  from output/fireD_headsM/measured/coord_698.npy
#
# Load #points: 393  from output/fireD_headsM/measured/coord_699.npy
#
# Load #points: 396  from output/fireD_headsM/measured/coord_700.npy
#
# Load #points: 415  from output/fireD_headsM/measured/coord_701.npy
#
# Load #points: 421  from output/fireD_headsM/measured/coord_702.npy
#
# ...
#
# Load #points: 103  from output/fireD_headsM/measured/coord_765.npy
#
# Load #points: 88  from output/fireD_headsM/measured/coord_766.npy
#
# Load #points: 75  from output/fireD_headsM/measured/coord_767.npy
#
# Load #points: 86  from output/fireD_headsM/measured/coord_768.npy
#
# Load #points: 85  from output/fireD_headsM/measured/coord_769.npy
#
# Load #points: 93  from output/fireD_headsM/measured/coord_770.npy
#
# Load #points: 75  from output/fireD_headsM/measured/coord_771.npy
#
# Load #points: 92  from output/fireD_headsM/measured/coord_772.npy
#
# Load #points: 86  from output/fireD_headsM/measured/coord_773.npy
#
# Load #points: 125  from output/fireD_headsM/measured/coord_774.npy
#
# Load #points: 140  from output/fireD_headsM/measured/coord_775.npy
#
# Load #points: 180  from output/fireD_headsM/measured/coord_776.npy
#
# Load #points: 164  from output/fireD_headsM/measured/coord_777.npy
#
# Load #points: 216  from output/fireD_headsM/measured/coord_778.npy
#
# Load #points: 203  from output/fireD_headsM/measured/coord_779.npy
#
# Load #points: 213  from output/fireD_headsM/measured/coord_780.npy
#
# Load #points: 234  from output/fireD_headsM/measured/coord_781.npy
#
# Load #points: 233  from output/fireD_headsM/measured/coord_782.npy
#
# Load #points: 228  from output/fireD_headsM/measured/coord_783.npy
#
# Load #points: 266  from output/fireD_headsM/measured/coord_784.npy
#
# Load #points: 236  from output/fireD_headsM/measured/coord_785.npy
#
# Load #points: 217  from output/fireD_headsM/measured/coord_786.npy
#
# Load #points: 202  from output/fireD_headsM/measured/coord_787.npy
#
# Load #points: 227  from output/fireD_headsM/measured/coord_788.npy
#
# Load #points: 217  from output/fireD_headsM/measured/coord_789.npy
#
# Load #points: 237  from output/fireD_headsM/measured/coord_790.npy
#
# Load #points: 225  from output/fireD_headsM/measured/coord_791.npy
#
# Load #points: 282  from output/fireD_headsM/measured/coord_792.npy
#
# Load #points: 256  from output/fireD_headsM/measured/coord_793.npy
#
# Load #points: 261  from output/fireD_headsM/measured/coord_794.npy
#
# Load #points: 269  from output/fireD_headsM/measured/coord_795.npy
#
# Load #points: 288  from output/fireD_headsM/measured/coord_796.npy
#
# Load #points: 251  from output/fireD_headsM/measured/coord_797.npy
#
# Load #points: 233  from output/fireD_headsM/measured/coord_798.npy
#
# Load #points: 269  from output/fireD_headsM/measured/coord_799.npy
#
# Load #points: 303  from output/fireD_headsM/measured/coord_800.npy
#
# Load #points: 259  from output/fireD_headsM/measured/coord_801.npy
#
# Load #points: 260  from output/fireD_headsM/measured/coord_802.npy
#
# Load #points: 320  from output/fireD_headsM/measured/coord_803.npy
#
# Load #points: 280  from output/fireD_headsM/measured/coord_804.npy
#
# Load #points: 308  from output/fireD_headsM/measured/coord_805.npy
#
# Load #points: 320  from output/fireD_headsM/measured/coord_806.npy
#
# Load #points: 343  from output/fireD_headsM/measured/coord_807.npy
#
# Load #points: 377  from output/fireD_headsM/measured/coord_808.npy
#
# Load #points: 339  from output/fireD_headsM/measured/coord_809.npy
#
# Load #points: 325  from output/fireD_headsM/measured/coord_810.npy
#
# Load #points: 352  from output/fireD_headsM/measured/coord_811.npy
#
# Load #points: 409  from output/fireD_headsM/measured/coord_812.npy
#
# Load #points: 448  from output/fireD_headsM/measured/coord_813.npy
#
# Load #points: 474  from output/fireD_headsM/measured/coord_814.npy
#
# Load #points: 504  from output/fireD_headsM/measured/coord_815.npy
#
# Load #points: 578  from output/fireD_headsM/measured/coord_816.npy
#
# Load #points: 536  from output/fireD_headsM/measured/coord_817.npy
#
# Load #points: 575  from output/fireD_headsM/measured/coord_818.npy
#
# Load #points: 549  from output/fireD_headsM/measured/coord_819.npy
#
# Load #points: 641  from output/fireD_headsM/measured/coord_820.npy
#
# Load #points: 624  from output/fireD_headsM/measured/coord_821.npy
#
# Load #points: 651  from output/fireD_headsM/measured/coord_822.npy
#
# Load #points: 724  from output/fireD_headsM/measured/coord_823.npy
#
# Load #points: 687  from output/fireD_headsM/measured/coord_824.npy
#
# Load #points: 700  from output/fireD_headsM/measured/coord_825.npy
#
# Load #points: 729  from output/fireD_headsM/measured/coord_826.npy
#
# Load #points: 697  from output/fireD_headsM/measured/coord_827.npy
#
# Load #points: 663  from output/fireD_headsM/measured/coord_828.npy
#
# Load #points: 697  from output/fireD_headsM/measured/coord_829.npy
#
# Load #points: 699  from output/fireD_headsM/measured/coord_830.npy
#
# Load #points: 636  from output/fireD_headsM/measured/coord_831.npy
#
# Load #points: 652  from output/fireD_headsM/measured/coord_832.npy
#
# Load #points: 643  from output/fireD_headsM/measured/coord_833.npy
#
# Load #points: 597  from output/fireD_headsM/measured/coord_834.npy
#
# Load #points: 606  from output/fireD_headsM/measured/coord_835.npy
#
# Load #points: 640  from output/fireD_headsM/measured/coord_836.npy
#
# Load #points: 641  from output/fireD_headsM/measured/coord_837.npy
#
# Load #points: 602  from output/fireD_headsM/measured/coord_838.npy
#
# Load #points: 605  from output/fireD_headsM/measured/coord_839.npy
#
# Load #points: 630  from output/fireD_headsM/measured/coord_840.npy
#
# Load #points: 612  from output/fireD_headsM/measured/coord_841.npy
#
# Load #points: 685  from output/fireD_headsM/measured/coord_842.npy
#
# Load #points: 716  from output/fireD_headsM/measured/coord_843.npy
#
# Load #points: 619  from output/fireD_headsM/measured/coord_844.npy
#
# Load #points: 625  from output/fireD_headsM/measured/coord_845.npy
#
# Load #points: 667  from output/fireD_headsM/measured/coord_846.npy
#
# Load #points: 697  from output/fireD_headsM/measured/coord_847.npy
#
# Load #points: 680  from output/fireD_headsM/measured/coord_848.npy
#
# Load #points: 652  from output/fireD_headsM/measured/coord_849.npy
#
# Load #points: 644  from output/fireD_headsM/measured/coord_850.npy
#
# Load #points: 622  from output/fireD_headsM/measured/coord_851.npy
#
# Load #points: 594  from output/fireD_headsM/measured/coord_852.npy
#
# Load #points: 641  from output/fireD_headsM/measured/coord_853.npy
#
# Load #points: 621  from output/fireD_headsM/measured/coord_854.npy
#
# Load #points: 606  from output/fireD_headsM/measured/coord_855.npy
#
# Load #points: 621  from output/fireD_headsM/measured/coord_856.npy
#
# Load #points: 623  from output/fireD_headsM/measured/coord_857.npy
#
# Load #points: 636  from output/fireD_headsM/measured/coord_858.npy
#
# Load #points: 656  from output/fireD_headsM/measured/coord_859.npy
#
# Load #points: 653  from output/fireD_headsM/measured/coord_860.npy
#
# Load #points: 604  from output/fireD_headsM/measured/coord_861.npy
#
# Load #points: 547  from output/fireD_headsM/measured/coord_862.npy
#
# Load #points: 526  from output/fireD_headsM/measured/coord_863.npy
#
# Load #points: 545  from output/fireD_headsM/measured/coord_864.npy
#
# Load #points: 516  from output/fireD_headsM/measured/coord_865.npy
#
# Load #points: 499  from output/fireD_headsM/measured/coord_866.npy
#
# Load #points: 458  from output/fireD_headsM/measured/coord_867.npy
#
# Load #points: 478  from output/fireD_headsM/measured/coord_868.npy
#
# Load #points: 439  from output/fireD_headsM/measured/coord_869.npy
#
# Load #points: 443  from output/fireD_headsM/measured/coord_870.npy
#
# Load #points: 377  from output/fireD_headsM/measured/coord_871.npy
#
# Load #points: 343  from output/fireD_headsM/measured/coord_872.npy
#
# Load #points: 288  from output/fireD_headsM/measured/coord_873.npy
#
# Load #points: 293  from output/fireD_headsM/measured/coord_874.npy
#
# Load #points: 277  from output/fireD_headsM/measured/coord_875.npy
#
# Load #points: 253  from output/fireD_headsM/measured/coord_876.npy
#
# Load #points: 256  from output/fireD_headsM/measured/coord_877.npy
#
# Load #points: 233  from output/fireD_headsM/measured/coord_878.npy
#
# Load #points: 251  from output/fireD_headsM/measured/coord_879.npy
#
# Load #points: 224  from output/fireD_headsM/measured/coord_880.npy
#
# Load #points: 206  from output/fireD_headsM/measured/coord_881.npy
#
# Load #points: 215  from output/fireD_headsM/measured/coord_882.npy
#
# Load #points: 186  from output/fireD_headsM/measured/coord_883.npy
#
# Load #points: 191  from output/fireD_headsM/measured/coord_884.npy
#
# Load #points: 152  from output/fireD_headsM/measured/coord_885.npy
#
# Load #points: 160  from output/fireD_headsM/measured/coord_886.npy
#
# Load #points: 117  from output/fireD_headsM/measured/coord_887.npy
#
# Load #points: 120  from output/fireD_headsM/measured/coord_888.npy
#
# Load #points: 100  from output/fireD_headsM/measured/coord_889.npy
#
# Load #points: 106  from output/fireD_headsM/measured/coord_890.npy
#
# Load #points: 93  from output/fireD_headsM/measured/coord_891.npy
#
# Load #points: 101  from output/fireD_headsM/measured/coord_892.npy
#
# Load #points: 94  from output/fireD_headsM/measured/coord_893.npy
#
# Load #points: 117  from output/fireD_headsM/measured/coord_894.npy
#
# Load #points: 121  from output/fireD_headsM/measured/coord_895.npy
#
# Load #points: 85  from output/fireD_headsM/measured/coord_896.npy
#
# Load #points: 131  from output/fireD_headsM/measured/coord_897.npy
#
# Load #points: 116  from output/fireD_headsM/measured/coord_898.npy
#
# Load #points: 99  from output/fireD_headsM/measured/coord_899.npy
#
# Load #points: 120  from output/fireD_headsM/measured/coord_900.npy
#
# Load #points: 103  from output/fireD_headsM/measured/coord_901.npy
#
# Load #points: 118  from output/fireD_headsM/measured/coord_902.npy
#
# Load #points: 117  from output/fireD_headsM/measured/coord_903.npy
#
# Load #points: 116  from output/fireD_headsM/measured/coord_904.npy
#
# Load #points: 95  from output/fireD_headsM/measured/coord_905.npy
#
# Load #points: 108  from output/fireD_headsM/measured/coord_906.npy
#
# Load #points: 121  from output/fireD_headsM/measured/coord_907.npy
#
# Load #points: 171  from output/fireD_headsM/measured/coord_908.npy
#
# Load #points: 190  from output/fireD_headsM/measured/coord_909.npy
#
# Load #points: 172  from output/fireD_headsM/measured/coord_910.npy
#
# Load #points: 177  from output/fireD_headsM/measured/coord_911.npy
#
# Load #points: 223  from output/fireD_headsM/measured/coord_912.npy
#
# Load #points: 163  from output/fireD_headsM/measured/coord_913.npy
#
# Load #points: 159  from output/fireD_headsM/measured/coord_914.npy
#
# Load #points: 201  from output/fireD_headsM/measured/coord_915.npy
#
# Load #points: 181  from output/fireD_headsM/measured/coord_916.npy
#
# Load #points: 216  from output/fireD_headsM/measured/coord_917.npy
#
# Load #points: 173  from output/fireD_headsM/measured/coord_918.npy
#
# Load #points: 178  from output/fireD_headsM/measured/coord_919.npy
#
# Load #points: 205  from output/fireD_headsM/measured/coord_920.npy
#
# Load #points: 197  from output/fireD_headsM/measured/coord_921.npy
#
# Load #points: 189  from output/fireD_headsM/measured/coord_922.npy
#
# Load #points: 224  from output/fireD_headsM/measured/coord_923.npy
#
# Load #points: 179  from output/fireD_headsM/measured/coord_924.npy
#
# Load #points: 217  from output/fireD_headsM/measured/coord_925.npy
#
# Load #points: 194  from output/fireD_headsM/measured/coord_926.npy
#
# Load #points: 166  from output/fireD_headsM/measured/coord_927.npy
#
# Load #points: 233  from output/fireD_headsM/measured/coord_928.npy
#
# Load #points: 179  from output/fireD_headsM/measured/coord_929.npy
#
# Load #points: 206  from output/fireD_headsM/measured/coord_930.npy
#
# Load #points: 206  from output/fireD_headsM/measured/coord_931.npy
#
# Load #points: 210  from output/fireD_headsM/measured/coord_932.npy
#
# Load #points: 263  from output/fireD_headsM/measured/coord_933.npy
#
# Load #points: 266  from output/fireD_headsM/measured/coord_934.npy
#
# Load #points: 319  from output/fireD_headsM/measured/coord_935.npy
#
# Load #points: 295  from output/fireD_headsM/measured/coord_936.npy
#
# Load #points: 248  from output/fireD_headsM/measured/coord_937.npy
#
# Load #points: 265  from output/fireD_headsM/measured/coord_938.npy
#
# Load #points: 347  from output/fireD_headsM/measured/coord_939.npy
#
# Load #points: 235  from output/fireD_headsM/measured/coord_940.npy
#
# Load #points: 481  from output/fireD_headsM/measured/coord_941.npy
#
# Load #points: 422  from output/fireD_headsM/measured/coord_942.npy
#
# Load #points: 320  from output/fireD_headsM/measured/coord_943.npy
#
# Load #points: 391  from output/fireD_headsM/measured/coord_944.npy
#
# Load #points: 345  from output/fireD_headsM/measured/coord_945.npy
#
# Load #points: 352  from output/fireD_headsM/measured/coord_946.npy
#
# Load #points: 430  from output/fireD_headsM/measured/coord_947.npy
#
# Load #points: 384  from output/fireD_headsM/measured/coord_948.npy
#
# Load #points: 320  from output/fireD_headsM/measured/coord_949.npy
#
# Load #points: 337  from output/fireD_headsM/measured/coord_950.npy
#
# Load #points: 306  from output/fireD_headsM/measured/coord_951.npy
#
# Load #points: 346  from output/fireD_headsM/measured/coord_952.npy
#
# Load #points: 296  from output/fireD_headsM/measured/coord_953.npy
#
# Load #points: 293  from output/fireD_headsM/measured/coord_954.npy
#
# Load #points: 307  from output/fireD_headsM/measured/coord_955.npy
#
# Load #points: 320  from output/fireD_headsM/measured/coord_956.npy
#
# Load #points: 357  from output/fireD_headsM/measured/coord_957.npy
#
# Load #points: 238  from output/fireD_headsM/measured/coord_958.npy
#
# Load #points: 315  from output/fireD_headsM/measured/coord_959.npy
#
# Load #points: 292  from output/fireD_headsM/measured/coord_960.npy
#
# Load #points: 282  from output/fireD_headsM/measured/coord_961.npy
#
# Load #points: 254  from output/fireD_headsM/measured/coord_962.npy
#
# Load #points: 223  from output/fireD_headsM/measured/coord_963.npy
#
# Load #points: 299  from output/fireD_headsM/measured/coord_964.npy
#
# Load #points: 365  from output/fireD_headsM/measured/coord_965.npy
#
# Load #points: 224  from output/fireD_headsM/measured/coord_966.npy
#
# Load #points: 245  from output/fireD_headsM/measured/coord_967.npy
#
# Load #points: 269  from output/fireD_headsM/measured/coord_968.npy
#
# Load #points: 278  from output/fireD_headsM/measured/coord_969.npy
#
# Load #points: 309  from output/fireD_headsM/measured/coord_970.npy
#
# Load #points: 266  from output/fireD_headsM/measured/coord_971.npy
#
# Load #points: 268  from output/fireD_headsM/measured/coord_972.npy
#
# Load #points: 275  from output/fireD_headsM/measured/coord_973.npy
#
# Load #points: 296  from output/fireD_headsM/measured/coord_974.npy
#
# Load #points: 400  from output/fireD_headsM/measured/coord_975.npy
#
# Load #points: 325  from output/fireD_headsM/measured/coord_976.npy
#
# Load #points: 306  from output/fireD_headsM/measured/coord_977.npy
#
# Load #points: 312  from output/fireD_headsM/measured/coord_978.npy
#
# Load #points: 294  from output/fireD_headsM/measured/coord_979.npy
#
# Load #points: 349  from output/fireD_headsM/measured/coord_980.npy
#
# Load #points: 430  from output/fireD_headsM/measured/coord_981.npy
#
# Load #points: 431  from output/fireD_headsM/measured/coord_982.npy
#
# Load #points: 457  from output/fireD_headsM/measured/coord_983.npy
#
# Load #points: 405  from output/fireD_headsM/measured/coord_984.npy
#
# Load #points: 313  from output/fireD_headsM/measured/coord_985.npy
#
# Load #points: 356  from output/fireD_headsM/measured/coord_986.npy
#
# Load #points: 390  from output/fireD_headsM/measured/coord_987.npy
#
# Load #points: 315  from output/fireD_headsM/measured/coord_988.npy
#
# Load #points: 350  from output/fireD_headsM/measured/coord_989.npy
#
# Load #points: 400  from output/fireD_headsM/measured/coord_990.npy
#
# Load #points: 378  from output/fireD_headsM/measured/coord_991.npy
#
# Load #points: 352  from output/fireD_headsM/measured/coord_992.npy
#
# Load #points: 330  from output/fireD_headsM/measured/coord_993.npy
#
# Load #points: 344  from output/fireD_headsM/measured/coord_994.npy
#
# Load #points: 382  from output/fireD_headsM/measured/coord_995.npy
#
# Load #points: 364  from output/fireD_headsM/measured/coord_996.npy
#
# Load #points: 367  from output/fireD_headsM/measured/coord_997.npy
#
# Load #points: 282  from output/fireD_headsM/measured/coord_998.npy
#
# Load #points: 342  from output/fireD_headsM/measured/coord_999.npy
